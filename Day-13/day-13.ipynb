# %%
############DEBUGGING#####################

# Describe Problem
def my_function():
  for i in range(1, 20):
    if i == 20:
      print("You got it")
my_function()

# This will not print 'You got it', because the for loop never be equals 20.
# One way to resolve this is doing the for loop be 1 to 20(1, 21)
def my_function_1():
  for i in range(1, 21):
    if i == 20:
      print("You got it")
my_function_1()

# Another way is doing the print in the end of the loop
def my_function_2():
    for i in range(1, 20):
        if i == 20:
            continue
    print("You got it")
my_function_2()

# The correct answer depend what i want to do.

# %%
# Reproduce the Bug
'''
from random import randint
dice_imgs = ["❶", "❷", "❸", "❹", "❺", "❻"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num])

# This code have a problem, somethings the error above show up and somethings the code run ok.
# IndexError: list index out of range
'''

# Correct the bug
from random import randint
dice_imgs = ["❶", "❷", "❸", "❹", "❺", "❻"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num-1])
# Out:
# ❶

# %%
# Play Computer
'''
year = 1994
if 1994 > 1980 and year < 1994:
if True and 1994 < 1994:
if True and False:
if False:
    ----print("You are a millenial.")----
next:
elif year > 1994:
elif 1994 > 1994:
elif False:
    ----print("You are a Gen Z.")----

Skip all the if statement
The code didn't print anything

'''
# Correct the code just include equals in one of the statements
year = int(input("What's your year of birth?"))
if year > 1980 and year < 1994:
  print("You are a millenial.")
elif year >= 1994:
  print("You are a Gen Z.")

# Now we correct the bug
# Out:
# You are a Gen Z.

# %%
'''
/home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:404(__build_constraints)  ->
    2    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/base.py:836(__iter__)
   40    0.000    0.012  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:668(__init__)
    2    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:3856(__getitem__)
    2    0.000    0.003  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:6482(drop_duplicates)
    2    0.016    0.282  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:9432(explode)
    4    0.001    0.062  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:10471(merge)
    2    0.000    0.161  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6366(astype)
    4    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:289(loc)
    4    0.000    0.011  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:867(__setitem__)
    4    0.000    0.010  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/reshape/concat.py:157(concat)
    2    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:1879(items)
    2    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:2224(unique)
   38    4.775  118.180  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:334(__build_combinations)
    2    0.001   32.917  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:431(<listcomp>)
    2    0.058    0.062  /home/vanessa/repository/arion-core/arion/optimizer/utils/pandas_utils.py:13(format_rows)
    2    0.000    0.000  {built-in method builtins.len}
   38    0.000    0.000  {method 'append' of 'list' objects}
    2    0.000    0.000  {method 'intersection' of 'set' objects}
    2    0.000    0.000  {method 'tolist' of 'numpy.ndarray' objects}

'''

# %%
'''
/home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:334(__build_combinations)  ->
    62728    0.061    0.324  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/arrays/_mixins.py:270(__getitem__)
    45438    0.094    2.068  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:2124(__iter__)
   547312    2.175   26.253  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:3856(__getitem__)
       38    0.001    0.080  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:6482(drop_duplicates)
    45362    0.124    4.774  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:11248(any)
      132    0.000    0.059  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:11265(all)
       38    0.000    0.001  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6187(__getattr__)
    45400    0.166    3.865  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6366(astype)
       38    0.000    0.023  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6551(copy)
      170    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:289(loc)
      132    0.001    0.038  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:867(__setitem__)
       38    0.000    0.039  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:1139(__getitem__)
   501818    0.513   53.037  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/ops/common.py:62(new_method)
   501780    0.274    9.466  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:6176(min)
   501780    0.324   12.818  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:6186(max)
       38    0.005    0.077  /home/vanessa/repository/arion-core/arion/optimizer/config/task.py:52(constants)
       38    0.000    0.000  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:354(<listcomp>)
   168936    0.074    0.074  /home/vanessa/repository/arion-core/arion/optimizer/utils/data_structures.py:21(set_bit)
   814265    0.221    0.221  /home/vanessa/repository/arion-core/arion/optimizer/utils/data_structures.py:37(check_bit)
   108588    0.024    0.024  /home/vanessa/repository/arion-core/arion/optimizer/utils/data_structures.py:48(__hash__)
    55556    0.023    0.023  /home/vanessa/repository/arion-core/arion/optimizer/utils/data_structures.py:51(__eq__)
    62728    0.035    0.052  /home/vanessa/repository/arion-core/arion/optimizer/utils/data_structures.py:54(copy)
     7670    0.004    0.005  {method 'add' of 'set' objects}
    62728    0.007    0.007  {method 'append' of 'collections.deque' objects}
   408554    0.067    0.067  {method 'append' of 'list' objects}
    63226    0.010    0.010  {method 'popleft' of 'collections.deque' objects}
      132    0.000    0.000  {method 'split' of 'str' objects}

/home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:431(<listcomp>)                        ->
    38    0.000    0.001  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6187(__getattr__)
    38    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:289(loc)
    38    0.000    0.009  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:1139(__getitem__)
    38    0.000    0.006  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/ops/common.py:62(new_method)
    38    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:708(values)
    38    0.033   32.899  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:463(__available_cattle_by_combination)

/home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:463(__available_cattle_by_combination)  ->
     38    0.000    1.591  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:668(__init__)
    612    0.004    0.224  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:3856(__getitem__)
     38    0.001    0.049  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:5990(reset_index)
     38    0.004    0.754  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:9629(melt)
    498    0.001    0.208  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:11265(all)
     38    0.000    0.023  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/generic.py:6551(copy)
    498    0.000    0.000  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:289(loc)
    498    0.003    0.118  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:867(__setitem__)
     76    0.000    0.013  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/ops/common.py:62(new_method)
     38    0.000    0.019  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/series.py:5278(isin)
  50606    0.004    0.006  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:484(<genexpr>)
     38    0.271   29.860  /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:489(<dictcomp>)
     38    0.000    0.000  {built-in method builtins.sorted}
    498    0.000    0.000  {method 'split' of 'str' objects}

    /home/vanessa/repository/arion-core/arion/optimizer/core/constraints/cattle_niche_constraint.py:489(<dictcomp>)           ->
        7670    0.067    3.743  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:3856(__getitem__)
        7670    0.041    1.635  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:8730(groupby)
        7670    0.025    0.888  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/frame.py:11248(any)
        7670    0.021   19.934  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1292(unique)
        7670    0.015    0.392  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1949(__getitem__)
        7670    0.006    0.006  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:289(loc)
        7670    0.019    2.986  /home/vanessa/anaconda3/envs/core-new/lib/python3.11/site-packages/pandas/core/indexing.py:1139(__getitem__)
        7670    0.004    0.004  {method 'split' of 'str' objects}
'''
