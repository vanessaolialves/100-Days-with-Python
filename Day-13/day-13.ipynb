# %%
############DEBUGGING#####################

# Describe Problem
def my_function():
  for i in range(1, 20):
    if i == 20:
      print("You got it")
my_function()

# This will not print 'You got it', because the for loop never be equals 20.
# One way to resolve this is doing the for loop be 1 to 20(1, 21)
def my_function_1():
  for i in range(1, 21):
    if i == 20:
      print("You got it")
my_function_1()

# Another way is doing the print in the end of the loop
def my_function_2():
    for i in range(1, 20):
        if i == 20:
            continue
    print("You got it")
my_function_2()

# The correct answer depend what i want to do.

# %%
# Reproduce the Bug
'''
from random import randint
dice_imgs = ["❶", "❷", "❸", "❹", "❺", "❻"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num])

# This code have a problem, somethings the error above show up and somethings the code run ok.
# IndexError: list index out of range
'''

# Correct the bug
from random import randint
dice_imgs = ["❶", "❷", "❸", "❹", "❺", "❻"]
dice_num = randint(1, 6)
print(dice_imgs[dice_num-1])
# Out:
# ❶

# %%
# Play Computer
'''
year = 1994
if 1994 > 1980 and year < 1994:
if True and 1994 < 1994:
if True and False:
if False:
    ----print("You are a millenial.")----
next:
elif year > 1994:
elif 1994 > 1994:
elif False:
    ----print("You are a Gen Z.")----

Skip all the if statement
The code didn't print anything

'''
# Correct the code just include equals in one of the statements
year = int(input("What's your year of birth?"))
if year > 1980 and year < 1994:
  print("You are a millenial.")
elif year >= 1994:
  print("You are a Gen Z.")

# Now we correct the bug
# Just add >= in elif
# Out:
# You are a Gen Z.

# %%
# Fix the Errors
'''
age = input("How old are you?")
if age > 18:
print("You can drive at age {age}.")


# 1- Error
# : Expected indented block
# Because we have a if, but not inside this if, and this is way for something
# How to correct
age = input("How old are you?")
if age > 18:
    print("You can drive at age {age}.")

# 2 - Error
# : TypeError: '>' not supported between instances of 'str' and 'int'
# Because the age is insert in age as a string, and the age is a int
# Change age to a int
# How to correct
age = int(input("How old are you?"))
if age > 18:
    print("You can drive at age {age}.")

# 3 - Error
# : The screen show us = You can drive at age {age}.
# We didn't put a f in the start of the string
# How to correct
age = int(input("How old are you?"))
if age > 18:
    print(f"You can drive at age {age}.")
'''


age = int(input("How old are you?"))
if age > 18:
    print(f"You can drive at age {age}.")

# Everything work in the correct way
# Out:
# You can drive at age 21.

# %%
#Print is Your Friend
'''
pages = 0
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words per page: "))
# Here is the problem, we are compare the variable
total_words = pages * word_per_page
print(total_words)
'''
pages = 0
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page = int(input("Number of words per page: "))
total_words = pages * word_per_page
print(f"pages = {pages}\nword_per_page = {word_per_page}")
print(total_words)
# Out:
# pages = 23
# word_per_page = 41
# 943

# %%
#Use a Debugger
'''
def mutate(a_list):
  b_list = []
  for item in a_list:
    new_item = item * 2
  b_list.append(new_item)
  print(b_list)

mutate([1,2,3,5,8,13])

# [26]

# https://pythontutor.com/visualize.html#mode=edit
# Search for another way to use debug

# The problem is we need indented in b_list to append

'''
def mutate(a_list):
  b_list = []
  for item in a_list:
    new_item = item * 2
    b_list.append(new_item)
  print(b_list)

mutate([1,2,3,5,8,13])

'''
> /debugger_in_my_code.py(6)mutate()
-> b_list.append(new_item)
(Pdb) new_item
2
(Pdb) b_list
[]
(Pdb) new_item
2
(Pdb) c
> /debugger_in_my_code.py(5)mutate()
-> breakpoint()
(Pdb) new_item
4
(Pdb) b_list
[2]
(Pdb) c
> /debugger_in_my_code.py(6)mutate()
-> b_list.append(new_item)
(Pdb) b_list
[2, 4]
(Pdb) c
> /debugger_in_my_code.py(5)mutate()
-> breakpoint()
(Pdb) b_list
[2, 4, 6]
(Pdb) c
> /debugger_in_my_code.py(6)mutate()
-> b_list.append(new_item)
(Pdb) b_list
[2, 4, 6, 10]
(Pdb) c
> /debugger_in_my_code.py(5)mutate()
-> breakpoint()
(Pdb) b_list
[2, 4, 6, 10, 16]
(Pdb) c
[2, 4, 6, 10, 16, 26]
'''
# Out:
# [2, 4, 6, 10, 16, 26]

# %%
# Final Debugging Tips

# If you need some help use stackoverflow
# https://stackoverflow.com/questions/tagged/python

# %%
# LESSON 25 DAY 13 - DEBUGGING ODD OR EVEN

'''
Instructions
Read this the code in main.py
Spot the problems 🐞.
Modify the code to fix the program.
Fix the code so that it works and passes the tests when you submit.

Hint
Review the previous lesson and go through the 10 steps to tackle these debugging problems.

1 # Which number do you want to check?
2 number = int(input())
3
4 if number % 2 = 0:
5   print("This is an even number.")
6 else:
7   print("This is an odd number.")

# Error line 4: if number % 2 = 0:
# Remember that single "=" is assignment.
# Double "==" is checking for equality
'''

number = int(input()) # Which number do you want to check?

if number % 2 == 0:
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
# This is an even number.

# %%
# LESSON 26 DAY 13 - DEBUGGING LEAP YEAR

'''
Read this the code in main.py
Spot the problems 🐞.
Modify the code to fix the program.
No shortcuts - don't copy-paste to replace the code entirely with a working solution.
Fix the code so that it works and when you hit submit it should pass all the tests.

1  # Which year do you want to check?
2  year = input()
3
4  if year % 4 == 0:
5    if year % 100 == 0:
6      if year % 400 == 0:
7        print("Leap year.")
8      else:
9        print("Not leap year.")
10   else:
11    print("Leap year.")
12 else:
13   print("Not leap year.")

# Error in line 4: TypeError: not all arguments converted during string formatting
# We have to correct line 2:
# TypeError without int() conversion
'''

# Which year do you want to check?
year = int(input())

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year.")
    else:
      print("Not leap year.")
  else:
    print("Leap year.")
else:
  print("Not leap year.")
# Out:
# Leap year.

# %%
#

'''
* Read this the code in main.py
* Spot the problems 🐞.
* Modify the code to fix the program.
* No shortcuts - don't copy-paste to replace the code entirely with a working solution.
The code needs to print the solution to the FizzBuzz game.

* Your program should print each number from 1 to x where x is the input number.
* However when the number is divisible by 3 then instead of printing the number it should print "Fizz".
* When the number is divisible by 5, then instead of printing the number it should print "Buzz".
* And if the number is divisible by both 3 and 5 e.g. 15 then instead of the number it should print "FizzBuzz".

Hint
There is more than one fix required.

1  target = int(input())
2  for number in range(1, target + 1):
3    if number % 3 == 0 or number % 5 == 0:
4      print("FizzBuzz")
5    if number % 3 == 0:
6      print("Fizz")
7    if number % 5 == 0:
8      print("Buzz")
9    else:
10    print([number])

"Print:
" [1]         -> Correct
" [2]         -> Correct
" FizzBuzz    -> Wrong
" Fizz        -> Correct
" [3]         -> Wrong
" [4]         -> Correct
" FizzBuzz    -> Wrong
" Buzz        -> Correct
" FizzBuzz    -> Wrong
" Fizz        -> Correct
" [6]         -> Wrong

# Error 1, in line 3:
# Use and, because we only print FizzBuzz when the both condition is True
# If any this condition is False, that will be False.
# Use and (not or)

# Error 2, in line 10:
# We print a list, instead a number
# Don't print number between [] (brackets)
# Remove square brackets []

# Error 3, in line 3, 5 and 7:
# The logical structure is wrong in this if.
# If one this is True, the others i couldn't verify.
# Use elif in line 5 and 7
# Use elif (not if)

'''

target = int(input())
for number in range(1, target + 1):
  if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz")
  elif number % 3 == 0:
    print("Fizz")
  elif number % 5 == 0:
    print("Buzz")
  else:
    print(number)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
