# %%
# Day 8

# Functions with Inputs
# Arguments e Parameters

# Project will by type of encryption
# Caesar Cipher - We will use this type of encryption

# A B C D E
# D E F G H
# Shifted by 3

# %%
# More functions
'''
def my_function():
    # Do this
    # Then do this
    # Finally do this
'''

# Review
# Create a function called greet().
# Write 3 print statements inside the function.
# Call the greet() function and run your code.

def greet():
    print('Hello Jack Bauer')
    print('How do you do Jack Bauer?')
    print('Isn\'t the weather nice today?')
    print()

# The same
greet()
greet()
greet()


# Functions with Inputs

'''
def my_function(something):
    # Do this with something
    # Then do this
    # Finally do this

my_function(123)

#    something = 123
#      .          .
#      .          .
# Parameter      Argument
'''

# Function that allows for input

def greet_with_name(name):
    print(f'Hello {name}')
    print(f'How do you do {name}?')
    print('Isn\'t the weather nice today?')
    print()

# Depend the parameter
greet_with_name('Jack Bauer')
greet_with_name('Billie')
greet_with_name('Angela')
# Out:
# Hello Jack Bauer
# How do you do Jack Bauer?
# Isn't the weather nice today?
#
# Hello Jack Bauer
# How do you do Jack Bauer?
# Isn't the weather nice today?
#
# Hello Jack Bauer
# How do you do Jack Bauer?
# Isn't the weather nice today?
#
# Hello Jack Bauer
# How do you do Jack Bauer?
# Isn't the weather nice today?
#
# Hello Billie
# How do you do Billie?
# Isn't the weather nice today?
#
# Hello Angela
# How do you do Angela?
# Isn't the weather nice today?

# %%
# Functions with more than 1 input
def greet_with(name, location):
    print(f'Hello {name}')
    print(f'What is it like in {location}')

greet_with('Jack Bauer', 'Nowhere')
print()
# Change the order to see what happen
greet_with( 'Nowhere','Jack Bauer')

'''
    Positional Arguments

def my_function(a, b, c):
    # Do this with a
    # Then do this with b
    # Finally do this with c

# if i want pass with arguments
# a = 1
# b = 2
# c = 3
# The order is extremely important

my_function(1,2,3)
'''
# Functions with keyword arguments
# This one don't need to be in order
print()
greet_with(name='Billie', location='USA')
print()
greet_with(location='USA', name='Billie')
# Out:
# Hello Jack Bauer
# What is it like in Nowhere
#
# Hello Nowhere
# What is it like in Jack Bauer
#
# Hello Billie
# What is it like in USA
#
# Hello Billie
# What is it like in USA
