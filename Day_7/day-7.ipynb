# %%
# Day 7 - Hangman

# Game Hangman: https://hangmanwordgame.com/?fca=1&success=0#/
# Explanation about the game: https://en.wikipedia.org/wiki/Hangman_(game)

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

print('Flow Chart Hangman')
img = mpimg.imread("Hangman_Flowchart.jpeg")
imgplot = plt.imshow(img)
plt.show()
# Out:
# Flow Chart Hangman

# %%
# How i do my hangman
import random

def print_list(list_things):
    for item in list_things:
        print(item, end=" ")

list_of_words = ['hello', 'yes', 'maybe', 'good', 'cat', 'absolutely', 'Japanese', 'judgment', 'saving',
                 'satisfaction', 'scenario', 'strength', 'string', 'struggle', 'suggestion', 'temperature',
                 'telephone', 'technology', 'themselves', 'together', 'tomorrow', 'tomato', 'tournament',
                 'understanding', 'unfortunately', 'uniform', 'union', 'unique', 'unit', 'United', 'wealthy',
                 'week', 'wear', 'welcome', 'weather', 'zone']
word = random.choice(list_of_words)
number_of_letter = len(word)
try_to_guess = number_of_letter*['-']
said_letter = set()
print_list(try_to_guess)
print(f' Lives: {life}')


life = 5
is_correct = number_of_letter

while life > 0 and is_correct > 0:
    letter = (input()).lower()
    count = 0
    if letter in said_letter:
        print('You have check this one!!!')
    else:
        said_letter.add(letter)
        for index in range(number_of_letter):
            if word[index] == letter:
                try_to_guess[index] = letter
                count += 1
                is_correct -= 1

    if count == 0:
        life -= 1

    print_list(try_to_guess)
    print(f' Lives: {life}')

if is_correct == 0:
    print('You Win!!!!')
else:
    print('Game Over')
    print('The word is ' + word)

print_list(try_to_guess)
# Out:
# - - - - - - - - - -  Lives: 5
# a - - - - - - - - -  Lives: 5
# a - - - - - - e - -  Lives: 5
# a - - - - u - e - -  Lives: 5
# a b - - - u - e - -  Lives: 5
# a b - - - u - e - y  Lives: 5
# a b s - - u - e - y  Lives: 5
# a b s - - u t e - y  Lives: 5
# a b s o - u t e - y  Lives: 5
# a b s o l u t e l y  Lives: 5
# You Win!!!!
# a b s o l u t e l y

# %%
# Doing the same thing in the course

# Hint about list in Python: https://developers.google.com/edu/python/lists?hl=pt-br#for-and-in

# Step 1
import random

word_list = ["aardvark", "baboon", "camel"]

#TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.
chosen_word = random.choice(word_list)

#TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.
guess_letter = input('Guess a letter: ').lower()

#TODO-3 - Check if the letter the user guessed (guess) is one of the leters in the chosen_word.
for letter in chosen_word:
    if letter == guess_letter:
        print('Right')
    else:
        print('Wrong')
# Out:
# Wrong
# Right
# Wrong
# Wrong
# Wrong

# %%
#Step 2

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')


#TODO-1: - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "apple", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.
display = len(chosen_word) * ['_']

# Another way to create a display with underscore
display = []
word_length = len(chosen_word)
for _ in range(word_length):
    display += "_"

guess_letter = input('Guess a letter: ').lower()

#TODO-2: - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "p" and the chosen word was "apple", then display should be ["_", "p", "p", "_", "_"].
count = 0
for letter in chosen_word:
    if letter == guess_letter:
        display[count] = guess_letter
    count += 1

# Another way to show letters in display
for position in range(word_length):
    letter = chosen_word[position]
    # If you want to understand better or to see what happen
    print(f"Current position: {position} Current letter: {letter} Guessed letter: {guess_letter}")
    if letter == guess_letter:
        display[position] = letter

#TODO-3: - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
#Hint - Don't worry about getting the user to guess the next letter. We'll tackle that in step 3.
print(display)
# Out:
# Pssst, the solution is aardvark.
# Current position: 0 Current letter: a Guessed letter: a
# Current position: 1 Current letter: a Guessed letter: a
# Current position: 2 Current letter: r Guessed letter: a
# Current position: 3 Current letter: d Guessed letter: a
# Current position: 4 Current letter: v Guessed letter: a
# Current position: 5 Current letter: a Guessed letter: a
# Current position: 6 Current letter: r Guessed letter: a
# Current position: 7 Current letter: k Guessed letter: a
# ['a', 'a', '_', '_', '_', 'a', '_', '_']

# %%
# Step 3

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

#TODO-1: - Use a while loop to let the user guess again. The loop should only stop once the user has guessed all the letters in the chosen_word and 'display' has no more blanks ("_"). Then you can tell the user they've won.
end_of_game = False

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    for position in range(word_length):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter

    print(display)

    #Check if there are no more "_" left in 'display'. Then all letters have been guessed.
    if not '_' in display:
        end_of_game = True

print('You win')
# Out:
# Pssst, the solution is aardvark.
# ['a', 'a', '_', '_', '_', 'a', '_', '_']
# ['a', 'a', 'r', '_', '_', 'a', 'r', '_']
# ['a', 'a', 'r', '_', '_', 'a', 'r', '_']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', '_']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', '_', 'a', 'r', 'k']
# ['a', 'a', 'r', 'd', 'v', 'a', 'r', 'k']
# You win

# %%
#Step 4

import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left.
#Set 'lives' to equal 6.
lives = 6

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
       # print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #TODO-2: - If guess is not a letter in the chosen_word,
    #Then reduce 'lives' by 1.
    #If lives goes down to 0 then the game should stop and it should print "You lose."
    if guess not in chosen_word:
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
    print(stages[lives])
# Out:
# Pssst, the solution is ardvark.
# a _ _ _ a _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# a _ _ _ a _ k
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# a _ _ _ a _ k
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# a _ _ _ a _ k
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# a r d _ a r k
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# a r d v a r k
# You win.
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...

# %%
#Step 5

# Hint:
# https://www.askpython.com/python/python-import-statement


import random


#TODO-1: - Update the word list to use the 'word_list' from hangman_words.py
#Delete this line: word_list = ["ardvark", "baboon", "camel"]
from hangman_words import word_list

chosen_word = random.choice(word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6

#TODO-3: - Import the logo from hangman_art.py and print it at the start of the game.
from hangman_art import logo
print(logo)

#Testing code
# print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    #TODO-4: - If the user has entered a letter they've already guessed, print the letter and let them know.
    if guess in display:
        print(f"You've already guessed {guess}")

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        #print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #Check if user is wrong.
    if guess not in chosen_word:
        #TODO-5: - If the letter is not in the chosen_word, print out the letter and let them know it's not in the word.
        print(f"You guessed {guess}, that's not in the word. You lose a life.")

        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-2: - Import the stages from hangman_art.py and make this error go away.
    from hangman_art import stages
    print(stages[lives])
# Out:
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# a _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# You've already guessed a
# a _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# You guessed u, that's not in the word. You lose a life.
# a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# You guessed y, that's not in the word. You lose a life.
# a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# You guessed b, that's not in the word. You lose a life.
# a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# You guessed e, that's not in the word. You lose a life.
# a _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# ...

# %%
# Change my started code

# How i do my hangman
import random
from hangman_art import logo, stages

def print_list(list_things):
    for item in list_things:
        print(item, end=" ")

list_of_words = ['hello', 'yes', 'maybe', 'good', 'cat', 'absolutely', 'Japanese', 'judgment', 'saving',
                 'satisfaction', 'scenario', 'strength', 'string', 'struggle', 'suggestion', 'temperature',
                 'telephone', 'technology', 'themselves', 'together', 'tomorrow', 'tomato', 'tournament',
                 'understanding', 'unfortunately', 'uniform', 'union', 'unique', 'unit', 'United', 'wealthy',
                 'week', 'wear', 'welcome', 'weather', 'zone']
word = random.choice(list_of_words)
number_of_letter = len(word)
try_to_guess = number_of_letter*['-']
said_letter = set()

life = 6
is_correct = number_of_letter
print(logo)
print_list(try_to_guess)
print(stages[life])

end_game = False


while not end_game:
    letter = (input()).lower()
    count = 0
    if letter in said_letter:
        print('You have check this one!!!')
    else:
        said_letter.add(letter)
        for index in range(number_of_letter):
            if word[index] == letter:
                try_to_guess[index] = letter
                count += 1
                is_correct -= 1

    if letter not in word:
        life -= 1
        if life == 0:
            end_game = True

    if '-' not in try_to_guess:
        end_game = True

    print_list(try_to_guess)
    print(stages[life])

if '-' not in try_to_guess:
    print('You Win!!!!')
else:
    print('Game Over')
    print('The word is ' + word)

print_list(try_to_guess)
# Out:
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# - - - - - - - - -
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# - - - - - - - - -
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# - e - e - - - - e
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# - e - e - - - - e
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# - e - e - - o - e
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# - e - e - - o - e
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# t e - e - - o - e
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# t e l e - - o - e
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# t e l e p - o - e
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
