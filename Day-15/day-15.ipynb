# %%
# IDE - Integrated Development Environment
# She will use PyCharm

# Install Python -> https://www.python.org/downloads/
# Install PyCharm -> https://www.jetbrains.com/pycharm/download/?section=windows

# Type of lint: https://peps.python.org/pep-0008/

# Keyboard PyCharm: https://www.jetbrains.com/help/pycharm/mastering-keyboard-shortcuts.html

# Emoji site: https://emojipedia.org/hot-beverage

# Windows keyboard tips:
#      https://support.microsoft.com/en-gb/windows/windows-keyboard-tips-and-tricks-588e0b72-0fff-6d3f-aeee-6e5116097942

# Mac keyboard tips:
#      https://support.apple.com/en-gb/guide/mac-help/mchlp1560/mac



def my_function(n1, n2):
    total = n1 + n2
    return total


my_function(4, 5)

# %% [markdown]
# # Make a Coffee Machine
#
# ## 1. Makes 3 hot flavours
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## 2. Coin Operated
#
# ![image-4.png](attachment:image-4.png)
#
#
# ## Program Requirements
#
# ![image-3.png](attachment:image-3.png)

# %%
import coffee_machine_by_me

coffee_machine_by_me

# Somethings need to be change
# Out:
# <module 'coffee_machine_by_me' from '/home/vanessa/cursos/python_class/day15/coffee_machine_by_me.py'>

# %% [markdown]
# > After correct some bugs
#
# > Running using the terminal
#
# ~~~ Bash Session
# >>> $ python coffee_machine_by_me.py
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert $1.5:
# How many quartes($0.25)? 5
# How many dimes($0.1)? 2
# How many nickles($0.05)? 1
# How many pennies($0.01)? 0
# The machine have $1.5 to future buy.
# Here is your espresso. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Machine Coffee Report
#   Water: 250ml
#   Milk: 200ml
#   Coffee: 82g
#   Money: $1.5
# What would you like? (espresso/latte/cappuccino): latte
# Please insert $2.5:
# How many quartes($0.25)? 10
# How many dimes($0.1)? 10
# How many nickles($0.05)? 10
# How many pennies($0.01)? 10
# Here is $1.6 dollars in change.
# The machine have $4.0 to future buy.
# Here is your latte. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Machine Coffee Report
#   Water: 50ml
#   Milk: 50ml
#   Coffee: 58g
#   Money: $4.0
# What would you like? (espresso/latte/cappuccino): report
# Machine Coffee Report
#   Water: 50ml
#   Milk: 50ml
#   Coffee: 58g
#   Money: $4.0
# What would you like? (espresso/latte/cappuccino): cappuccino
# “Sorry there is not enough water.
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert $1.5:
# How many quartes($0.25)? 3
# How many dimes($0.1)? 1
# How many nickles($0.05)? 1
# How many pennies($0.01)? 1
# Sorry that's not enough money. Money refunded.
# What would you like? (espresso/latte/cappuccino): off
# ~~~

# %%
import coffee_machine_by_me

coffee_machine_by_me

# Better test in terminal
# Out:
# Machine Coffee Report
#   Water: 300ml
#   Milk: 200ml
#   Coffee: 100g
#   Money: $0
# Please insert $1.5:
# Here is $0.26 dollars in change.
# The machine have $1.5 to future buy.
# Here is your espresso. Enjoy!
# Please insert $3.0:
# Here is $2.4 dollars in change.
# The machine have $4.5 to future buy.
# Here is your cappuccino. Enjoy!
# Machine Coffee Report
#   Water: 0ml
#   Milk: 100ml
#   Coffee: 58g
#   Money: $4.5
# “Sorry there is not enough water.
# Machine Coffee Report
#   Water: 0ml
#   Milk: 100ml
#   Coffee: 58g
#   Money: $4.5
# <module 'coffee_machine_by_me' from '/home/vanessa/cursos/python_class/day15/coffee_machine_by_me.py'>

# %% [markdown]
#  > After the class
#
#
# ~~~ Bash Session
# >>> $ python coffee_machine_by_angela.py
# What would you like? (espresso/latte/cappuccino): latte
# Please insert coins.
# How many quarters?: 12
# How many dimes?: 12
# How many nickles?: 12
# How many pennies?: 12
# Here is $2.42 in change.
# Here is your latte ☕.
# What would you like? (espresso/latte/cappuccino): report
# Water: 100ml
# Milk: 50ml
# Coffee: 76g
# Money: $2.5
# What would you like? (espresso/latte/cappuccino): latte
# Sorry there is not enough water.
# What would you like? (espresso/latte/cappuccino): off
# >>> $ python coffee_machine_by_angela.py
# What would you like? (espresso/latte/cappuccino): report
# Water: 300ml
# Milk: 200ml
# Coffee: 100g
# Money: $0
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 1
# How many dimes?: 1
# How many nickles?: 1
# How many pennies?: 1
# Sorry that's not enough money. Money refunded.
# What would you like? (espresso/latte/cappuccino): report
# Water: 300ml
# Milk: 200ml
# Coffee: 100g
# Money: $0
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 10
# How many dimes?: 10
# How many nickles?: 10
# How many pennies?: 10
# Here is $2.6 in change.
# Here is your espresso ☕. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Water: 250ml
# Milk: 200ml
# Coffee: 82g
# Money: $1.5
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 5
# How many dimes?: 5
# How many nickles?: 5
# How many pennies?: 5
# Here is $0.55 in change.
# Here is your espresso ☕. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Water: 200ml
# Milk: 200ml
# Coffee: 64g
# Money: $3.0
# What would you like? (espresso/latte/cappuccino): latte
# Sorry there is not enough water.
# What would you like? (espresso/latte/cappuccino): cappuccino
# Sorry there is not enough water.
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 4
# How many dimes?: 4
# How many nickles?: 4
# How many pennies?: 4
# Here is $0.14 in change.
# Here is your espresso ☕. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Water: 150ml
# Milk: 200ml
# Coffee: 46g
# Money: $4.5
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 4
# How many dimes?: 4
# How many nickles?: 1
# How many pennies?: 4
# Sorry that's not enough money. Money refunded.
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 4
# How many dimes?: 4
# How many nickles?: 2
# How many pennies?: 0
# Here is $0.0 in change.
# Here is your espresso ☕. Enjoy!
# What would you like? (espresso/latte/cappuccino): report
# Water: 100ml
# Milk: 200ml
# Coffee: 28g
# Money: $6.0
# What would you like? (espresso/latte/cappuccino): espresso
# Please insert coins.
# How many quarters?: 10
# How many dimes?: 10
# How many nickles?: 10
# How many pennies?: 10
# Here is $2.6 in change.
# Here is your espresso ☕. Enjoy!
# What would you like? (espresso/latte/cappuccino): espresso
# Sorry there is not enough water.
# What would you like? (espresso/latte/cappuccino): report
# Water: 50ml
# Milk: 200ml
# Coffee: 10g
# Money: $7.5
# What would you like? (espresso/latte/cappuccino): off
# ~~~

# %%
import coffee_machine_by_angela

coffee_machine_by_angela

# Better test in terminal
# Out:
# Water: 200ml
# Milk: 200ml
# Coffee: 64g
# Money: $0
# Please insert coins.
# Here is $2.6 in change.
# Here is your espresso ☕. Enjoy!
# Water: 150ml
# Milk: 200ml
# Coffee: 46g
# Money: $1.5
# Sorry there is not enough water.
# Sorry there is not enough water.
# Please insert coins.
# Here is $0.96 in change.
# Here is your espresso ☕. Enjoy!
# Water: 100ml
# Milk: 200ml
# Coffee: 28g
# Money: $3.0
# <module 'coffee_machine_by_angela' from '/home/vanessa/cursos/python_class/day15/coffee_machine_by_angela.py'>
